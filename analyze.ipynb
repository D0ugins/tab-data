# %% [markdown]
# # Setup

# %%
DATA_FILE = f"rounds"
DATA_PATH = f'./data/{DATA_FILE}'
TABDATA_PATH = './data/tabroom'

# %%
import pandas as pd
from sqlalchemy import create_engine
from tqdm.notebook import tqdm
import json

db = create_engine("postgresql://postgres:password@localhost:5432/debate-cards")
pd.set_option('display.float_format', '{:.3f}'.format)
tqdm.pandas()
# %matplotlib inline

# %%
try:
  rounds = pd.read_feather(DATA_PATH + '.feather')
except FileNotFoundError:
  query = """
    SELECT 
      round."roundId", round.side, round.tournament, round.round, round.opponent, round.judge, round.report, round."opensourcePath", round."caselistUpdatedAt", 
      team."teamId", team.name as "teamName", team."displayName" as "teamDisplayName", team.notes, team."debater1First", team."debater1Last", team."debater2First", team."debater2Last", 
      school."schoolId", school.name as "schoolName", school."displayName" as "schoolDisplayName", school.state, school."chapterId", 
      caselist."caselistId", caselist.name as "caselistName", caselist."displayName" as "caselistDisplayName", caselist.year, caselist.event, caselist.level, caselist."teamSize",
      file.id as "fileId"
      FROM "Round" round 
      JOIN "Team" team ON team."teamId" = round."teamId"
      JOIN "School" school on school."schoolId" = team."schoolId"
      JOIN "Caselist" caselist on caselist."caselistId" = school."caselistId"
      LEFT JOIN "File" file ON file."roundId" = round.id;
  """
  rounds = pd.read_sql(query, db)  
  rounds.to_feather(DATA_PATH + '.feather')

# %%
rounds.to_csv('./datasets/caselists/rounds.csv')

# %%
try:
  cites = pd.read_feather(DATA_PATH + '_cites.feather')
except FileNotFoundError:
  query = """ SELECT id, "citeId", title, cites, "roundId" FROM "Cite" """
  cites = pd.read_sql(query, db)
  print("Loaded")
  cites.to_feather(DATA_PATH + '_cites.feather')

# %%
cites.to_csv('./datasets/caselist/cites.csv')

# %%
import glob
import re
tournIds = sorted([int(re.search(r'/(\d+)\.json', path).group(1)) for path in glob.glob(f'{TABDATA_PATH}/*.json')])

# %%
from collections import Counter

abbrs = Counter()
for i in tqdm(tournIds):
  with open(f'{TABDATA_PATH}/{i}.json') as f:
    try:
      tourn = json.load(f)
      if 'categories' not in tourn: continue
      for category in tourn['categories']:
        for event in category['events']:
          abbrs[event['abbr'] or category['abbr']] += 1
    except KeyboardInterrupt:
      raise KeyboardInterrupt
    except:
      print(f'Failed: {i}')
abbrs

# %%
print("\n".join([f"{abbr or 'None'}: {str(abbrs[abbr])}" for abbr in abbrs]))

# %%
from bs4 import BeautifulSoup
import requests

def loadDoc(url):
  response = requests.get(url)
  return BeautifulSoup(response.text)

# %%
def loadTeamRecord(id1: int, id2: int):
  doc = loadDoc(f"https://www.tabroom.com/index/results/team_lifetime_record?id1={id1}&id2={id2}")
  divs = doc.select(".main > div.nospace.padtop")[1:]
  tables = [pd.read_html(str(div.find('table')))[0] for div in divs]
  names = [div.find('h5').text.strip() for div in divs]
  return pd.concat(tables, keys=[(name[-4:], name[0:-5]) for name in names])

# %%
# tournNum = 22381
tournNum = None

# %%
# with open(f'{TABDATA_PATH}/{tournNum}.json') as f:
#   tourn = json.load(f)
tourn = None

# %% [markdown]
# # Load

# %%
policyNames = ['cx', 'pol']
def isPolicy(s: str):
  if s is None: return False
  s = s.lower()
  return any([name in s for name in policyNames])

def findPolicyEvents(tourn):
  if 'categories' not in tourn: return []
  events = []
  for category in tourn['categories']:
    if isPolicy(category['abbr']) or isPolicy(category['name']):
      events += category['events']
    else:
      for event in category['events']:
        if isPolicy(event['abbr']) or isPolicy(event['name']): events += [event]
  return events

def optional(dest: dict, src: dict, field: str):
  if field in src: dest[field] = src[field]

# %%
def getBallots(round, json_tourn, entries: dict[int, set[int]]):
  json_round = json_tourn | {
    "roundId": int(round['id']),
    "type": round['type'],
    "name": round['name'],
    "protocol_name": round['protocol_name'],
    "start_time": round['start_time']
  }
  optional(json_round, round, 'label')
  optional(json_round, round, 'flights')
  optional(json_round, round, 'runoff')

  ballots = []
  if 'sections' in round:
    for section in round['sections']:
      json_section = json_round | {
        "sectionId": int(section['id']),
        "room": section['room'],
        "letter": section['letter']
      }
      optional(json_section, section, 'bye')
      if 'ballots' in section:
        for ballot in section['ballots']:
          json_ballot = json_section | {
            'ballotId': int(ballot['id']),
            'panelId': ballot['panel'],
            'entry': ballot['entry']
          }
          optional(json_ballot, ballot, 'judge_started')
          optional(json_ballot, ballot, 'started_by')
          optional(json_ballot, ballot, 'entered_by')
          optional(json_ballot, ballot, 'audited_by')
          optional(json_ballot, ballot, 'side')
          optional(json_ballot, ballot, 'speakerorder')

          optional(json_ballot, ballot, 'judge')
          optional(json_ballot, ballot, 'judge_code')
          optional(json_ballot, ballot, 'chair')
          optional(json_ballot, ballot, 'judge_first')
          optional(json_ballot, ballot, 'judge_last')

          optional(json_ballot, ballot, 'entry_code')
          optional(json_ballot, ballot, 'entry_name')

          optional(json_ballot, ballot, 'forfeit')
          if 'scores' in ballot:
            scores = ballot['scores']
            winlossScores = [s for s in scores if s['tag'] == 'winloss']
            if len(winlossScores) == 1: json_ballot['winloss'] = winlossScores[0]['value']
            
            pointScores = {s['speaker']: s['value'] for s in scores if s['tag'] =='point' and 'speaker' in s and 'value' in s}
            speakers = set(pointScores.keys())
            if len(speakers) < 2 and ballot['entry'] in entries:
              speakers = entries[ballot['entry']]
            else:
              entries[ballot['entry']] = speakers
            
            for i, speaker in enumerate(sorted(speakers)):
              json_ballot[f'speaker{i + 1}Id'] = speaker
              if speaker in pointScores: json_ballot[f'speaker{i + 1}Score'] = pointScores[speaker]
          ballots += [json_ballot]
  # else:
    # print(f"Missing sections for round {round['id']}")
  return ballots

# %%
def getResults(resultSet, json_tourn, entries: dict[int, set[int]]):
  json_resultSet = json_tourn | {
    "label": resultSet['label'],
    "coach": resultSet['coach'],
    "generated": resultSet['generated'],
  }
  results = []
  if 'results' not in resultSet or 'result_keys' not in resultSet: return results
  resultKeys = {resultKey['id']: resultKey for resultKey in resultSet['result_keys']}
  for result in resultSet['results']:
    json_result = json_resultSet | {}
    optional(json_result, result, 'rank')
    optional(json_result, result, 'place')
    optional(json_result, result, 'percentile')
    optional(json_result, result, 'entry')
    optional(json_result, result, 'student')
    optional(json_result, result, 'school')
    optional(json_result, result, 'round')
    # If result has entry and student, add student to that entry
    if 'student' in result and 'entry' in result:
      entry = result['entry']
      if entry not in entries: entries[entry] = set()
      entries[entry].add(result['student'])

    if 'values' in result:
      for i, result_value in enumerate(result['values']):
        if 'result_key' not in result_value or 'value' not in result_value: continue
        if result_value['result_key'] not in resultKeys: continue
        tag = resultKeys[result_value['result_key']]['tag']
        try:
          value = float(result_value['value'])
        except ValueError:
          value = result_value['value']
        results.append(json_result | {
          "tag": tag,
          "value": value
        })
  return results

# %%
# try:
#   # noinspection
#   len(policyTournIds)
# except NameError:
policyTournIds = set()

def processTourn(id):
  with open(f'{TABDATA_PATH}/{id}.json') as f:
    tourn = json.load(f)
    json_tourn = {
      'tournamentId': id,
      'tournamentName': tourn['name'],
      'tournamentStart': tourn['start'],
      'tournamentEnd': tourn['end'],
      'city': tourn['city'],
      'state': tourn['state'],
      'country': tourn['country'],
      'webname': tourn['webname'],
      'timezone': tourn['timezone']
    }

    events = findPolicyEvents(tourn)
    ballots = []
    results = []
    entries = {}
    for event in events:
      if 'result_sets' in event:
        policyTournIds.add(id)
        for resultSet in event['result_sets']:
          results += getResults(resultSet, json_tourn, entries)
      if 'rounds' in event:
        policyTournIds.add(id)
        for round in event['rounds']:
          ballots += getBallots(round, json_tourn, entries)
    return results, ballots

# %%
resultData = []
ballotData = []
try:
  ids = policyTournIds
  # raise
except:
  print("Using all tournament ids")
  ids = tournIds
for i in tqdm(sorted(ids)):
  try:
    results, ballots = processTourn(i)
    resultData += results
    ballotData += ballots
  except KeyboardInterrupt:
    raise KeyboardInterrupt
  except Exception as e:
    print(f'Failed: {i}')
    raise e

resultData = pd.DataFrame(resultData)
resultData.to_feather(DATA_PATH + '_results.feather')
print("Saved results") 
ballotData = pd.DataFrame(ballotData)
ballotData.to_feather(DATA_PATH + '_ballots.feather')
print("Saved ballots")
# Out:
#   0%|          | 0/5167 [00:00<?, ?it/s]
# Saved results
# Saved ballots

# %%
ballotData = pd.read_feather(DATA_PATH + "_ballots.feather")

# %%
with open('./data/policyTournIds.json', 'w') as f:
  json.dump(sorted(policyTournIds), f)
len(policyTournIds)

# %%
teamSet = set(ballotData.groupby(['speaker1Id', 'speaker2Id'], as_index=False).count()[['speaker1Id', 'speaker2Id']].itertuples(index=False))
with open('./data/teamSet.json', 'w') as f:
  json.dump(sorted(teamSet), f)
len(teamSet)
# Out:
# 44217

# %% [markdown]
# # Analyze

# %% [markdown]
# ## Ballots

# %%
teamSet = set(ballotData[ballotData.speaker2Id.notna()].groupby(['speaker1Id', 'speaker2Id']).groups)

# %%
len(ballotData.sectionId.unique())
# Out:
# 353756

# %%
ballotData.groupby('side').winloss.describe().loc[[1, 2]]
# Out:
#            count  mean   std   min   25%   50%   75%   max
# side
# 1.000 307884.000 0.518 0.500 0.000 0.000 1.000 1.000 2.000
# 2.000 307496.000 0.483 0.500 0.000 0.000 0.000 1.000 2.000

# %%
ballotData.count()
# Out:
# tournamentId       836627
# tournamentName     836627
# tournamentStart    836627
# tournamentEnd      836627
# city               588265
# state              835122
# country            835122
# webname            830128
# timezone           836627
# roundId            836627
# type               836627
# name               836627
# protocol_name      832762
# start_time         835546
# label              301065
# sectionId          836627
# room               836627
# letter             835546
# ballotId           836627
# panelId            836627
# entry              836627
# side               831425
# judge              807951
# judge_first        807588
# judge_last         807226
# entry_code         836508
# entry_name         836415
# flights            817940
# bye                 22382
# winloss            615442
# speaker1Id         573385
# speaker1Score      467194
# speaker2Id         554057
# speaker2Score      452077
# judge_code         229318
# chair               10412
# entered_by         562401
# speaker3Id            874
# speaker3Score         806
# forfeit              4258
# judge_started      520184
# speaker4Id             89
# speaker4Score          77
# speaker5Id             31
# speaker5Score          25
# speakerorder         7708
# runoff                541
# audited_by            137
# speaker6Id             10
# speaker6Score          10
# speaker7Id              5
# speaker7Score           5
# speaker8Id              5
# speaker8Score           5
# speaker9Id              5
# speaker9Score           5
# started_by         116935
# dtype: int64

# %%
(ballotData.entry_name.str.find('&') >= 0).mean()
# Out:
# 0.8982652962431287

# %%
ballotData.entry_code.iloc[550000:]
# Out:
# 550000       Concordia Boals & Spindler
# 550001          UMKC Mitchell & Willett
# 550002         UTD Beutelspacher & Kaul
# 550003     Wyomin' Mitchell & Radcliffe
# 550004    Texas Coltzer & Marriott-Voss
#                       ...
# 836622         Shahzeb Khan & Eesh Pant
# 836623         Shahzeb Khan & Eesh Pant
# 836624            Jason Fan & Lesley Xu
# 836625        Shreyas Jain & Steve Pait
# 836626           Angad Hayer & Moon Liu
# Name: entry_code, Length: 286627, dtype: object

# %%
ballotData.tournamentName.value_counts().iloc[0:10]
# Out:
# National Speech and Debate Tournament                   15580
# Glenbrooks Speech and Debate Tournament                 11725
# University of Michigan HS Debate Tournament             10276
# Nationals Prep                                           8993
# Greenhill Fall Classic                                   8317
# CHSSA Simulation Tournament                              8192
# Cal Invitational UC Berkeley                             7676
# Tournament of Champions                                  6387
# University of Michigan HS Tournament                     5561
# John Edie Holiday Debates Hosted by The Blake School     5144
# Name: tournamentName, dtype: int64

# %%
ballotData \
  .groupby(['speaker1Id', 'speaker2Id']) \
  .filter(lambda x: len(x) > 20) \
  .groupby(['speaker1Id', 'speaker2Id']) \
  .winloss.aggregate(['mean', 'sum', 'count']) \
  .sort_values(['sum', 'mean'], ascending=False) \
  .iloc[0:15]
# Out:
#                        mean     sum  count
# speaker1Id speaker2Id
# 203981.000 309087.000 0.818 356.000    435
# 700291.000 700295.000 0.696 344.000    494
# 583152.000 586494.000 0.740 321.000    434
# 736265.000 736266.000 0.717 276.000    385
# 706156.000 706162.000 0.647 266.000    411
# 974070.000 975610.000 0.609 257.000    422
# 553706.000 553709.000 0.622 242.000    389
# 380151.000 501530.000 0.696 215.000    309
# 520709.000 520710.000 0.781 214.000    274
# 480617.000 553146.000 0.627 212.000    338
# 307561.000 520648.000 0.581 205.000    353
# 713611.000 713617.000 0.679 197.000    290
# 475426.000 475471.000 0.794 196.000    247
# 720647.000 720650.000 0.659 191.000    290
# 705776.000 705779.000 0.623 190.000    305

# %%
def getTeamBallots(id1: int, id2: int) -> pd.DataFrame:
  id1, id2 = sorted([id1, id2])
  return ballotData[(ballotData.speaker1Id == id1) & (ballotData.speaker2Id == id2)]

# %%
def compareDownload(id1: int, id2: int):
  team = getTeamBallots(id1, id2)
  teamTourns = team \
    .groupby(['tournamentId', 'tournamentName']) \
    .agg({'tournamentStart': 'first', 'tournamentId': 'count'}) \
    .rename(columns={'tournamentId': 'ballotCount'}) \
    .sort_values('tournamentStart', ascending=False)
  years = teamTourns.tournamentStart.str[0:4]
  reset = teamTourns.reset_index()
  downloadCounts = reset.set_index([years, reset.tournamentName.str.strip()]).ballotCount.astype('Int64') # Nullable integer
  
  record = loadTeamRecord(id1, id2)
  recordCounts = record.Decision.str.len().groupby(level=[0, 1], sort=False).sum()
  
  return pd.DataFrame({'download': downloadCounts, 'record': recordCounts })

# %%
id1, id2 = 203981, 309087
compareDownload(id1, id2)
# Out:
#                                                          download  record
# 2015 Ibis Debates at the University of Miami                    4       4
# 2016 Cal Invitational at Berkeley HS Tournament                14      14
#      John Edie Holiday Debates hosted by Blake                 10      10
#      NY Fall Face Off at Mamaroneck HS                         12      12
#      New York City Invitational Debate and Speech To...        18      18
#      Policy Early Bird at Wake Forest                        <NA>      12
#      Samford University Bishop Guild                           14      14
#      The Tradition                                              9       9
#      University of Michigan HS Debate Tournament                7      15
# 2017 Barkley Forum for High Schools                          <NA>       9
#      Crestian Policy Classic                                    9      21
#      Glenbrooks Speech and Debate Tournament                   10      10
#      Greenhill Fall Classic                                    15      15
#      John Edie Holiday Debates Hosted by The Blake S...        22      22
#      NY Fall Faceoff at Mamaroneck HS                          16      15
#      National Speech and Debate Season Opener hosted...        12      12
#      New York City Invitational Debate and Speech To...        21      21
#      Tournament of Champions                                    7       7
#      University of Michigan HS Debate Tournament               22      30
#      Wake Forest Fall Classic                                  15      16
# 2018 Cal Invitational  UC Berkeley                             17      17
#      Glenbrooks Speech and Debate Tournament                   19      19
#      Greenhill Fall Classic                                    38      36
#      John Edie Holiday Debates Hosted by The Blake S...        19      19
#      Lexington Winter Invitational                             15      15
#      New York City Invitational Debate and Speech To...        15      15
#      Tournament of Champions                                   10      10
#      Trevian Invitational                                      21      21
# 2019 Barkley Forum for High Schools                          <NA>      12
#      Cal Invitational UC Berkeley                              24      24
#      Justin Wilson Debates Pace RR                           <NA>      12
#      Lexington Winter Invitational                              7       7
#      Southern Bell Forum MBA                                    6       6
#      Tournament of Champions                                    7       7

# %%
(253 + 253) - (453)
# Out:
# 53

# %%
teamGroups = ballotData.groupby(['speaker1Id', 'speaker2Id'])

# %%
teamGroups.ngroups
# Out:
# 44217

# %%
# %timeit (715369, 715370) in teamSet
# Out:
# 61 ns ± 2.94 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
codes = ballotData.entry_code.dropna()
schools = codes[codes.str.match(r'.+ [A-Z]{2}$')].str.replace(r' [A-Z]{2}$', '', regex=True)

# %%
codes.str.match(r'.+ [A-Z]{2}$')

# %%
schoolCounts = schools.str.lower().str.replace(r'[^a-zA-Z]', '', regex=True).value_counts()
schoolCounts.iloc[0:20]
# Out:
# lexington                7066
# montgomerybell           6694
# glenbrooksouth           6433
# glenbrooknorth           6405
#                          6179
# nileswest                5961
# peninsula                5172
# newtrier                 4890
# notredame                4728
# mamaroneck               4713
# collegeprep              4231
# woodward                 4024
# liberty                  4022
# greenhill                3831
# nilesnorth               3665
# damien                   3565
# stmarksschooloftexas     3426
# kansas                   3138
# liberalartsandscience    3115
# brooklyntechnical        3072
# Name: entry_code, dtype: int64

# %%
caselistSchoolCounts = rounds[rounds.event == 'cx'].schoolDisplayName.str.lower().str.replace(r'[^a-zA-Z]', '', regex=True).value_counts()
caselistSchoolCounts.iloc[0:20]
# Out:
# kansas            3740
# jesuitdallas      3001
# glenbrooknorth    2913
# woodward          2733
# michigan          2679
# emory             2585
# lexington         2512
# minnesota         2471
# newtrier          2447
# glenbrooksouth    2349
# peninsula         2343
# wakeforest        2199
# kentucky          2139
# georgemason       2028
# georgetown        1959
# liberty           1904
# northwestern      1868
# nileswest         1828
# westminster       1780
# stmarks           1765
# Name: schoolDisplayName, dtype: int64

# %%
opponents = rounds[rounds.event == 'cx'].opponent.dropna()
opponentSchoolNames = opponents[opponents.str.match(r'.+ ?[A-Z]{2}$')].str.replace(r' [A-Z]{2}$', '', regex=True)
opponentSchoolCounts = opponentSchoolNames.str.lower().str.replace(r'[^a-zA-Z]', '', regex=True).value_counts()
opponentSchoolCounts
# Out:
# emory                 2114
# kansas                2023
# michigan              1928
# mba                   1874
# peninsula             1825
#                       ...
# navymarywashington       1
# webet                    1
# minnesotaemory           1
# indianamichigan          1
# northestern              1
# Name: opponent, Length: 4610, dtype: int64

# %%
# TODO: Add caselist opponent field to comparison
mergedCounts = pd.DataFrame({'caselist': caselistSchoolCounts, 'tabroom': schoolCounts, 'opponent': opponentSchoolCounts})
mergedCounts['max'] = mergedCounts.max(axis=1)
mergedCounts = mergedCounts.sort_values('max', ascending=False).drop(columns='max')
mergedCounts
# Out:
#                  caselist  tabroom  opponent
# lexington        2512.000 7066.000  1298.000
# montgomerybell   1477.000 6694.000   612.000
# glenbrooksouth   2349.000 6433.000   758.000
# glenbrooknorth   2913.000 6405.000   690.000
#                       NaN 6179.000     3.000
# ...                   ...      ...       ...
# southmainecc          NaN      NaN     1.000
# medinavalley          NaN      NaN     1.000
# georgetownnight       NaN      NaN     1.000
# southlakecarrol       NaN      NaN     1.000
# zombies               NaN      NaN     1.000
#
# [7034 rows x 3 columns]

# %%
mergedCounts.to_csv(DATA_PATH + "_schools.csv")

# %%
print(mergedCounts.to_string())
# Out:
#                                                                                                               caselist  tabroom  opponent
# Lexington                                                                                                     2512.000 7066.000  1293.000
# Montgomery Bell                                                                                               1477.000 6694.000   611.000
# Glenbrook South                                                                                               2349.000 6433.000   750.000
# Glenbrook North                                                                                               2913.000 6405.000   674.000
# Niles West                                                                                                    1828.000 5961.000  1589.000
# Peninsula                                                                                                     2343.000 5172.000  1817.000
# New Trier                                                                                                     2447.000 4890.000  1411.000
# Notre Dame                                                                                                    1584.000 4728.000  1235.000
# Mamaroneck                                                                                                    1441.000 4713.000   924.000
# College Prep                                                                                                  1555.000 4231.000   786.000
# Woodward                                                                                                      2733.000 4024.000  1246.000
# Liberty                                                                                                       1904.000 4022.000  1541.000
# Greenhill                                                                                                     1437.000 3831.000  1428.000
# Kansas                                                                                                        3740.000 3138.000  2020.000
# Niles North                                                                                                   1141.000 3665.000   929.000
# Damien                                                                                                        1489.000 3565.000  1046.000
# Liberal Arts and Science                                                                                           NaN 3115.000   266.000
# Brooklyn Technical                                                                                             236.000 3072.000   115.000
# Berkeley Prep                                                                                                  734.000 3031.000   913.000
# Jesuit Dallas                                                                                                 3001.000      NaN    19.000
# Bronx Science                                                                                                  772.000 3001.000   661.000
# Westminster                                                                                                   1780.000 2836.000  1503.000
# Barstow                                                                                                       1434.000 2830.000   735.000
# Stuyvesant                                                                                                     395.000 2792.000   501.000
# CK McClatchy                                                                                                   828.000 2752.000   448.000
# Michigan                                                                                                      2679.000 1701.000  1917.000
# Harker                                                                                                         746.000 2624.000   490.000
# Carrollton School of the Sacred Heart                                                                              NaN 2585.000   202.000
# Emory                                                                                                         2585.000 1881.000  2112.000
# Binghamton                                                                                                     470.000 2509.000   559.000
# Minnesota                                                                                                     2471.000  887.000  1196.000
# Westwood                                                                                                      1138.000 2361.000  1318.000
# Little Rock Central                                                                                            889.000 2335.000   602.000
# Georgetown Day                                                                                                 478.000 2297.000   437.000
# Coppell                                                                                                       1161.000 2295.000   844.000
# Interlake                                                                                                     1101.000 2272.000   699.000
# George Mason                                                                                                  2028.000 2246.000   868.000
# Wake Forest                                                                                                   2199.000 1805.000   671.000
# Wayzata                                                                                                        697.000 2165.000   579.000
# Kentucky                                                                                                      2139.000  753.000  1192.000
# NYU                                                                                                            839.000 2070.000   515.000
# Maine East                                                                                                     581.000 2043.000   580.000
# Crossings Christian                                                                                            291.000 2017.000   327.000
# Edina                                                                                                          563.000 2005.000   587.000
# Lane Tech                                                                                                      303.000 1987.000   494.000
# Whitney Young                                                                                                  720.000 1982.000   574.000
# Alpharetta                                                                                                    1360.000 1960.000  1017.000
# Georgetown                                                                                                    1959.000  705.000  1093.000
# Chattahoochee                                                                                                  688.000 1954.000   513.000
# Washburn Rural                                                                                                1126.000 1933.000   529.000
# Cornell                                                                                                        943.000 1921.000   470.000
# ADL                                                                                                                NaN 1883.000   409.000
# Northwestern                                                                                                  1868.000 1030.000   976.000
# MBA                                                                                                                NaN   12.000  1838.000
# USN                                                                                                            176.000 1837.000   507.000
# Rowland Hall                                                                                                  1294.000 1818.000   830.000
# Eagan                                                                                                          230.000 1815.000   388.000
# Polytechnic                                                                                                    545.000 1814.000   468.000
# North Broward Prep                                                                                             537.000 1803.000   117.000
# St Mark's School of Texas                                                                                          NaN 1791.000   155.000
# St Marks                                                                                                      1765.000      NaN   873.000
# Ballot Test                                                                                                        NaN 1747.000       NaN
# Kent Denver                                                                                                    911.000 1728.000   453.000
# Montgomery Bell Academy                                                                                       1666.000      NaN    39.000
# Walter Payton                                                                                                 1123.000 1661.000   884.000
# Solorio                                                                                                        636.000 1657.000   439.000
# Northside                                                                                                          NaN 1632.000    70.000
# St. Mark's School of Texas                                                                                         NaN 1608.000     2.000
# Pace                                                                                                               NaN 1607.000   503.000
# Dartmouth                                                                                                     1600.000  604.000  1144.000
# Head Royce                                                                                                     417.000 1598.000   469.000
# Meadows                                                                                                        303.000 1595.000   420.000
# Missouri State                                                                                                1593.000  478.000   672.000
# Harvard                                                                                                       1582.000 1428.000  1207.000
# Caddo Magnet                                                                                                  1010.000 1572.000   372.000
# Iowa City West                                                                                                 655.000 1560.000   363.000
# Cal Berkeley                                                                                                  1558.000      NaN   134.000
# Univ Of Chicago Lab                                                                                                NaN 1556.000   120.000
# Michigan State                                                                                                1538.000  800.000   442.000
# Strath Haven                                                                                                   640.000 1502.000   301.000
# Sonoma                                                                                                          81.000 1498.000   267.000
# Liberal Arts And Science Academy                                                                              1480.000      NaN     2.000
# Blue Valley Southwest                                                                                         1479.000 1191.000   352.000
# Jesuit CP                                                                                                          NaN 1475.000    92.000
# Northview                                                                                                      608.000 1471.000   482.000
# Homestead                                                                                                      265.000 1467.000   212.000
# Hebron                                                                                                         344.000 1456.000   367.000
# James Madison                                                                                                 1121.000 1440.000   312.000
# Nevada Union                                                                                                   282.000 1417.000   241.000
# Jesuit                                                                                                             NaN 1413.000   968.000
# Kinkaid                                                                                                        537.000 1398.000   571.000
# Isidore Newman                                                                                                 370.000 1395.000   343.000
# Westminster Schools                                                                                                NaN 1389.000     8.000
# Liberal Arts And Science                                                                                      1367.000      NaN     1.000
# Thomas Jefferson HSST                                                                                            3.000 1367.000    96.000
# Lawrence Free State                                                                                           1348.000  893.000   367.000
# Wyoming                                                                                                       1346.000  815.000   589.000
# ModernBrain                                                                                                     78.000 1343.000    77.000
# Oakton                                                                                                          50.000 1343.000    71.000
# Georgia                                                                                                       1326.000  674.000   707.000
# Casady                                                                                                         291.000 1320.000   294.000
# Okemos                                                                                                          88.000 1290.000   229.000
# Oklahoma                                                                                                       606.000 1275.000   426.000
# United States Military                                                                                             NaN 1269.000    20.000
# Johns Creek                                                                                                    307.000 1264.000   324.000
# Northside CP                                                                                                       NaN 1263.000    44.000
# Northside                                                                                                     1252.000  334.000   829.000
# Newark Science                                                                                                 169.000 1246.000   170.000
# Carrollton Sacred Heart                                                                                       1222.000   92.000    70.000
# Cypress Bay                                                                                                    704.000 1214.000   369.000
# Marist                                                                                                         178.000 1211.000   255.000
# West Des Moines Valley                                                                                         355.000 1210.000   192.000
# Walter Payton CP                                                                                                   NaN 1199.000    36.000
# McDonogh                                                                                                       437.000 1184.000   284.000
# Calvert Hall                                                                                                   571.000 1184.000   301.000
# Leland                                                                                                         448.000 1174.000   283.000
# GBN                                                                                                                NaN   66.000  1166.000
# Newark Tech                                                                                                     24.000 1165.000   155.000
# Rowland Hall-St. Mark's                                                                                            NaN 1165.000       NaN
# Baltimore City                                                                                                     NaN 1162.000   170.000
# Lowell                                                                                                         506.000 1150.000   374.000
# Bellarmine                                                                                                    1148.000  257.000   600.000
# Pine Crest                                                                                                     443.000 1128.000   437.000
# Blue Valley North                                                                                             1126.000 1047.000   367.000
# Thomas Jefferson                                                                                               329.000 1117.000   242.000
# Reagan                                                                                                         685.000 1115.000   527.000
# Rosemount                                                                                                      185.000 1111.000   203.000
# Leon Goldstein                                                                                                  84.000 1085.000   108.000
# Dowling Catholic                                                                                               140.000 1078.000   143.000
# Minneapolis South                                                                                              557.000 1075.000   345.000
# Monmouth                                                                                                        15.000 1073.000    73.000
# Rochester                                                                                                      217.000 1070.000   161.000
# LASA                                                                                                               NaN   76.000  1061.000
# Wake                                                                                                               NaN  183.000  1059.000
# UNLV                                                                                                          1054.000  472.000   626.000
# Skyline                                                                                                         34.000 1053.000   164.000
# Archbishop Mitty                                                                                               376.000 1031.000   207.000
# Libert                                                                                                             NaN 1030.000       NaN
# Houston                                                                                                        505.000 1029.000   563.000
# Juan Diego Catholic                                                                                                NaN 1025.000    59.000
# SA Harlem North Central                                                                                         11.000 1020.000     2.000
# Millard North                                                                                                  142.000 1016.000   276.000
# Edgemont                                                                                                       346.000 1015.000   337.000
# Wichita East                                                                                                   952.000 1010.000   389.000
# Garfield                                                                                                       111.000 1005.000   197.000
# Texas                                                                                                          448.000 1004.000   867.000
# Dougherty Valley                                                                                               137.000  999.000   164.000
# GBS                                                                                                                NaN   25.000   991.000
# Hendrickson                                                                                                    987.000  890.000   493.000
# SA Hudson Yards                                                                                                    NaN  983.000     8.000
# Heritage Hall                                                                                                  159.000  973.000   195.000
# Alpharetta HS                                                                                                      NaN  955.000    19.000
# Lansing                                                                                                        949.000  675.000   474.000
# University                                                                                                      49.000  946.000   146.000
# Green Valley                                                                                                   249.000  928.000   243.000
# H.H. Dow                                                                                                           NaN  927.000     3.000
# Bellarmine                                                                                                         NaN  925.000    48.000
# Broad Run                                                                                                       94.000  922.000    80.000
# Shawnee Mission East                                                                                           919.000  692.000   239.000
# Homewood-Flossmoor                                                                                                 NaN  895.000    45.000
# St. Vincent De Paul                                                                                                NaN  891.000       NaN
# SA Ditmas Park                                                                                                     NaN  880.000     2.000
# Moore                                                                                                           93.000  879.000   134.000
# SA Harlem West                                                                                                   2.000  873.000     7.000
# Bronx HS Of Science                                                                                                NaN  871.000    11.000
# Gulliver Prep                                                                                                  278.000  870.000   227.000
# Unionville                                                                                                     156.000  859.000   156.000
# Mary Washington                                                                                                849.000  198.000   193.000
# Lovejoy                                                                                                        273.000  843.000   164.000
# Washington                                                                                                     226.000  837.000   223.000
# Wylie E. Groves                                                                                                    NaN  835.000       NaN
# St George's                                                                                                        NaN  827.000       NaN
# Indiana                                                                                                        824.000  705.000   694.000
# Baylor                                                                                                         823.000  743.000   725.000
# Jenks                                                                                                          302.000  820.000   172.000
# Trinity                                                                                                        813.000  780.000   574.000
# Oak Park and River Forest                                                                                          NaN  811.000    70.000
# Cal State Fullerton                                                                                              4.000  809.000    97.000
# SF Roosevelt                                                                                                       NaN  809.000   146.000
# Rosemont                                                                                                        56.000  806.000    77.000
# St Francis                                                                                                     284.000  806.000   171.000
# Pittsburgh                                                                                                     797.000  271.000   302.000
# Iowa City                                                                                                      152.000  795.000   247.000
# Blue Valley West                                                                                               788.000  573.000   270.000
# Northwood                                                                                                      389.000  785.000   231.000
# Coppell 9th                                                                                                      4.000  785.000    21.000
# Union                                                                                                            2.000  781.000   110.000
# Wichita State                                                                                                  776.000  417.000   324.000
# LanTec                                                                                                             NaN  774.000     2.000
# Weber State                                                                                                     16.000  769.000   159.000
# Loyola                                                                                                         352.000  766.000   181.000
# Chantilly                                                                                                        7.000  759.000     2.000
# Chicago Lab Schools                                                                                                NaN  756.000    27.000
# Whitney M. Young Magnet                                                                                            NaN  752.000       NaN
# Kamiak                                                                                                         135.000  743.000    94.000
# Blue Valley Northwest                                                                                          701.000  739.000   164.000
# Talented and Gifted Magnet                                                                                         NaN  732.000     4.000
# McQueen                                                                                                         25.000  731.000   214.000
# Minneapolis Washburn                                                                                            33.000  730.000    69.000
# Gonzaga                                                                                                        727.000  491.000   458.000
# Nevada Las Vegas                                                                                                   NaN  711.000    15.000
# Central Oklahoma                                                                                               709.000  458.000    96.000
# Rutgers-Newark                                                                                                     NaN  707.000    53.000
# Jesuit                                                                                                             NaN  703.000       NaN
# West HS SLC                                                                                                        NaN  692.000   111.000
# Copper Hills                                                                                                   112.000  689.000   143.000
# Ferris                                                                                                         290.000  688.000   125.000
# Long Branch                                                                                                        NaN  682.000    11.000
# UC Berkeley                                                                                                        NaN  682.000   146.000
# Grapevine                                                                                                      191.000  680.000   220.000
# GleNor                                                                                                             NaN  679.000       NaN
# Manhattan                                                                                                      163.000  674.000   125.000
# SA East Flatbush                                                                                                   NaN  672.000     2.000
# Winston Churchill                                                                                              622.000  671.000   351.000
# Bingham                                                                                                        350.000  667.000   107.000
# Marquette Univ                                                                                                     NaN  667.000     8.000
# Shawnee Mission South                                                                                          613.000  662.000   248.000
# Vanderbilt                                                                                                     192.000  661.000   107.000
# SA Midtown West                                                                                                  1.000  661.000     2.000
# OES                                                                                                                NaN  660.000   256.000
# GeoMas                                                                                                             NaN  659.000     4.000
# Wayne State                                                                                                    659.000  616.000   453.000
# Hunter                                                                                                             NaN  655.000    68.000
# West                                                                                                           297.000  651.000   226.000
# NilWes                                                                                                             NaN  650.000       NaN
# Highland Park Senior                                                                                            13.000  649.000    35.000
# Lincoln East                                                                                                   224.000  648.000   107.000
# Oakland Tech                                                                                                    30.000  648.000    65.000
# GMU                                                                                                                NaN  532.000   646.000
# Topeka Seaman                                                                                                      NaN  645.000    14.000
# Rufus King                                                                                                      55.000  636.000    70.000
# Millard West                                                                                                    72.000  635.000    82.000
# Texas-Austin                                                                                                   635.000      NaN     8.000
# Iowa                                                                                                           603.000  631.000   605.000
# Downtown Magnets                                                                                               355.000  630.000   116.000
# MSU                                                                                                                NaN  106.000   622.000
# Travis                                                                                                             NaN  622.000       NaN
# Samford                                                                                                        604.000  415.000   449.000
# UT Dallas                                                                                                          NaN  601.000   113.000
# Calhoun                                                                                                        206.000  601.000   215.000
# Blake                                                                                                          446.000  600.000   185.000
# SLC West                                                                                                       318.000  599.000   201.000
# Dulles                                                                                                         151.000  595.000   154.000
# Lincoln                                                                                                          2.000  595.000    88.000
# La Crosse Central                                                                                               15.000  588.000    46.000
# Airline                                                                                                        116.000  582.000   127.000
# Wheeler                                                                                                         24.000  581.000    50.000
# CUNY                                                                                                            11.000  580.000     8.000
# Walter Payton                                                                                                      NaN  576.000     5.000
# Derby                                                                                                          143.000  574.000   205.000
# UTD                                                                                                            520.000   89.000   574.000
# George Washington                                                                                              132.000  571.000   178.000
# WalPay                                                                                                             NaN  570.000    17.000
# Texas-Dallas                                                                                                   567.000      NaN     3.000
# Fort Atkinson                                                                                                      NaN  563.000    24.000
# James Logan                                                                                                    353.000  555.000   246.000
# Monmou                                                                                                             NaN  552.000       NaN
# Hamilton                                                                                                       105.000  548.000    76.000
# SA Harlem East                                                                                                     NaN  547.000       NaN
# Kapaun Mount Carmel                                                                                            545.000  382.000    53.000
# Carrollton                                                                                                         NaN  254.000   542.000
# Missouri - Kansas City                                                                                             NaN  541.000     5.000
# Ingraham                                                                                                       136.000  540.000    92.000
# Lynbrook                                                                                                        21.000  540.000    42.000
# Pace Academy                                                                                                   538.000   49.000     2.000
# Riverwood                                                                                                       87.000  538.000   144.000
# UMKC                                                                                                           537.000  447.000   412.000
# Detroit Country Day                                                                                             45.000  536.000    50.000
# Chaminade                                                                                                      534.000  433.000   277.000
# GleSou                                                                                                             NaN  531.000       NaN
# Emporia                                                                                                        229.000  521.000   288.000
# Madison East                                                                                                    32.000  520.000    16.000
# Miami                                                                                                           54.000  518.000   140.000
# Woodgrove                                                                                                          NaN  517.000    11.000
# Lane Tech College Prep H.S.                                                                                        NaN  515.000       NaN
# Chaminade CP                                                                                                       NaN  513.000    23.000
# Desert Vista                                                                                                   138.000  512.000   129.000
# NewSci                                                                                                             NaN  511.000       NaN
# Guymon                                                                                                             NaN  511.000    31.000
# Eagle                                                                                                          130.000  509.000    72.000
# Arizona State                                                                                                  298.000  506.000    87.000
# Westwo                                                                                                             NaN  497.000     2.000
# Florida                                                                                                        230.000  496.000   187.000
# Bingha                                                                                                             NaN  491.000     4.000
# Lawrence                                                                                                       324.000  486.000   269.000
# USC                                                                                                            477.000   98.000   484.000
# SPASH                                                                                                           88.000  482.000    61.000
# Traverse City Central                                                                                          116.000  481.000    52.000
# Evanston Twp                                                                                                     9.000  480.000    35.000
# JamMad                                                                                                             NaN  479.000       NaN
# North Broward                                                                                                  416.000   21.000   478.000
# Ronald Reagan                                                                                                    1.000  477.000    29.000
# Centennial                                                                                                         NaN  476.000   128.000
# West Virginia                                                                                                   69.000  472.000    94.000
# West Georgia                                                                                                   211.000  469.000   289.000
# Pine Crest Preparatory                                                                                             NaN  469.000     7.000
# Kansas State                                                                                                   466.000  306.000   219.000
# Towson                                                                                                          37.000  466.000    78.000
# Concordia                                                                                                      152.000  465.000   210.000
# NilNor                                                                                                             NaN  464.000       NaN
# Louisville                                                                                                      37.000  464.000   244.000
# Milton                                                                                                          95.000  463.000   138.000
# Cal                                                                                                                NaN   15.000   462.000
# Lewis and Clark                                                                                                 11.000  461.000    29.000
# Davis Senior                                                                                                    12.000  460.000    58.000
# Henry W Grady                                                                                                  357.000  459.000   135.000
# Von Steuben                                                                                                        NaN  458.000    62.000
# Milpitas                                                                                                       171.000  457.000    51.000
# JBS Law Magnet                                                                                                     NaN  454.000     6.000
# Hybrid                                                                                                             NaN  453.000     4.000
# Modern                                                                                                             NaN  453.000    13.000
# Decatur                                                                                                        377.000  450.000   211.000
# Galloway                                                                                                       155.000  447.000   143.000
# Asbury Park                                                                                                        NaN  446.000     5.000
# Leon M. Goldstein                                                                                                  NaN  446.000       NaN
# Oak Park River Forest                                                                                          443.000      NaN    49.000
# KCKCC                                                                                                           69.000  442.000    69.000
# Taipei American                                                                                                267.000  440.000   216.000
# Stevens Point Area Senior High (SPASH)                                                                             NaN  439.000     5.000
# NewTri                                                                                                             NaN  438.000       NaN
# Topeka                                                                                                         135.000  438.000    71.000
# SA Bed-Stuy                                                                                                        NaN  437.000     1.000
# Elkins                                                                                                          39.000  435.000    82.000
# Presentation                                                                                                   142.000  434.000   141.000
# Jones CP                                                                                                         9.000  433.000    20.000
# Roseville Area                                                                                                     NaN  433.000    22.000
# Rutgers                                                                                                        152.000  248.000   432.000
# Shawnee Heights                                                                                                  7.000  432.000    20.000
# Canyon Crest                                                                                                   430.000  316.000   224.000
# Pittsburgh Central Catholic                                                                                    167.000  430.000    94.000
# 2                                                                                                                  NaN  430.000       NaN
# Navy                                                                                                           391.000  429.000   404.000
# Silver Creek                                                                                                    22.000  429.000    46.000
# University Prep                                                                                                  5.000  429.000    21.000
# Michigan State University                                                                                      427.000      NaN     2.000
# La Salle                                                                                                       214.000  427.000   103.000
# USMA                                                                                                               NaN  426.000    94.000
# Cathedral Prep                                                                                                  50.000  425.000    71.000
# Sonoma Academy                                                                                                 421.000   18.000     4.000
# Thomas Kelly                                                                                                     9.000  421.000    36.000
# Maize                                                                                                          312.000  419.000   204.000
# JMU                                                                                                                NaN  205.000   418.000
# Baltimore City College                                                                                          87.000  417.000    53.000
# Dallas Highland Park                                                                                            11.000  414.000    43.000
# Kansas City Kansas CC                                                                                              NaN  413.000     3.000
# UniSta                                                                                                             NaN  408.000     4.000
# ...
# FullertonBoston College                                                                                            NaN      NaN     1.000
# Salado -                                                                                                           NaN      NaN     1.000
# Salem Hill                                                                                                         NaN      NaN     1.000
# FullertonBinghampton                                                                                               NaN      NaN     1.000
# Salem Hils                                                                                                         NaN      NaN     1.000
# Full aff distribution                                                                                              NaN      NaN     1.000
# Full Aff distribution UT                                                                                           NaN      NaN     1.000
# Ft Atkinson                                                                                                        NaN      NaN     1.000
# Salpoint Catholic                                                                                                  NaN      NaN     1.000
# GBC                                                                                                                NaN      NaN     1.000
# GBH                                                                                                                NaN      NaN     1.000
# Sac StateUSC                                                                                                       NaN      NaN     1.000
# Saint Ignatius Cleveland                                                                                           NaN      NaN     1.000
# GT                                                                                                                 NaN      NaN     1.000
# GSU Long Beach                                                                                                     NaN      NaN     1.000
# GNB                                                                                                                NaN      NaN     1.000
# Sacramento                                                                                                         NaN      NaN     1.000
# GMUIllinois                                                                                                        NaN      NaN     1.000
# GMU-Minn                                                                                                           NaN      NaN     1.000
# GMU SS V Liberty                                                                                                   NaN      NaN     1.000
# GMU SS V JMU                                                                                                       NaN      NaN     1.000
# GMU -                                                                                                              NaN      NaN     1.000
# Sacremento State                                                                                                   NaN      NaN     1.000
# GMLiberty                                                                                                          NaN      NaN     1.000
# Saginaw High School                                                                                                NaN      NaN     1.000
# GEORGIA STATE                                                                                                      NaN      NaN     1.000
# Saint George                                                                                                       NaN      NaN     1.000
# GC                                                                                                                 NaN      NaN     1.000
# Saint Iggy                                                                                                         NaN      NaN     1.000
# GBN-                                                                                                               NaN      NaN     1.000
# George Mason-Weber State                                                                                           NaN      NaN     1.000
# SIoux Falls Lincoln                                                                                                NaN      NaN     1.000
# Rowlett                                                                                                            NaN      NaN     1.000
# RutgersJames Madison                                                                                               NaN      NaN     1.000
# RutgersOakton                                                                                                      NaN      NaN     1.000
# RutgersOaktonCC                                                                                                    NaN      NaN     1.000
# RutgersRochester                                                                                                   NaN      NaN     1.000
# RutgersTowson Swing Team                                                                                           NaN      NaN     1.000
# Goldberg                                                                                                           NaN      NaN     1.000
# Godly                                                                                                              NaN      NaN     1.000
# Glnebrook South                                                                                                    NaN      NaN     1.000
# Glenrbook South                                                                                                    NaN      NaN     1.000
# Glennbrooks South                                                                                                  NaN      NaN     1.000
# S Eugene HS                                                                                                        NaN      NaN     1.000
# S Eugene High School                                                                                               NaN      NaN     1.000
# Glennbrook North                                                                                                   NaN      NaN     1.000
# Glenbrooke North                                                                                                   NaN      NaN     1.000
# SA BRONX                                                                                                           NaN      NaN     1.000
# Glenbrook South                                                                                                    NaN      NaN     1.000
# Glenbrook Northwest                                                                                                NaN      NaN     1.000
# GlenRose                                                                                                           NaN      NaN     1.000
# Goldberg Academy                                                                                                   NaN      NaN     1.000
# RutgersCUNY                                                                                                        NaN      NaN     1.000
# SA East Flatbush -                                                                                                 NaN      NaN     1.000
# Rutgers-NewarkCal State Fullerton                                                                                  NaN      NaN     1.000
# Royse                                                                                                              NaN      NaN     1.000
# Grapvine                                                                                                           NaN      NaN     1.000
# RuRaL iNdEpEnDeNt                                                                                                  NaN      NaN     1.000
# Grand Rapids                                                                                                       NaN      NaN     1.000
# Rugters                                                                                                            NaN      NaN     1.000
# Runoff SLC West                                                                                                    NaN      NaN     1.000
# Grand Rapid City                                                                                                   NaN      NaN     1.000
# Rural Bluniors Washburn Rural                                                                                      NaN      NaN     1.000
# Grand Prarie                                                                                                       NaN      NaN     1.000
# Rustin                                                                                                             NaN      NaN     1.000
# Goodard                                                                                                            NaN      NaN     1.000
# GonzagaWake                                                                                                        NaN      NaN     1.000
# Gonzaga prep                                                                                                       NaN      NaN     1.000
# Gonzaga Wake                                                                                                       NaN      NaN     1.000
# Rutgera                                                                                                            NaN      NaN     1.000
# Gonzaga                                                                                                            NaN      NaN     1.000
# Rutgers- Newark                                                                                                    NaN      NaN     1.000
# Glen Rose ISD                                                                                                      NaN      NaN     1.000
# Glen Brook North                                                                                                   NaN      NaN     1.000
# George MasonWake Forest                                                                                            NaN      NaN     1.000
# SAN ANGELO CENTRAL                                                                                                 NaN      NaN     1.000
# Georgetown NYU                                                                                                     NaN      NaN     1.000
# SDVP                                                                                                               NaN      NaN     1.000
# Georgetown Day -                                                                                                   NaN      NaN     1.000
# Georgetown Da                                                                                                      NaN      NaN     1.000
# Georgetown Bay                                                                                                     NaN      NaN     1.000
# GeorgeTown                                                                                                         NaN      NaN     1.000
# SF Roo                                                                                                             NaN      NaN     1.000
# GeorgeMason                                                                                                        NaN      NaN     1.000
# SF Roosevelts                                                                                                      NaN      NaN     1.000
# SF State                                                                                                           NaN      NaN     1.000
# George Washington Colorado                                                                                         NaN      NaN     1.000
# SFA                                                                                                                NaN      NaN     1.000
# George Washingston                                                                                                 NaN      NaN     1.000
# George Washingon                                                                                                   NaN      NaN     1.000
# George Washing                                                                                                     NaN      NaN     1.000
# George Town                                                                                                        NaN      NaN     1.000
# SHAWNEE MISSION SOUTH                                                                                              NaN      NaN     1.000
# Georgetown-UMW                                                                                                     NaN      NaN     1.000
# Georgetown-Wake                                                                                                    NaN      NaN     1.000
# Glebrooks South                                                                                                    NaN      NaN     1.000
# GeorgetownHarvard                                                                                                  NaN      NaN     1.000
# SA Harlem North                                                                                                    NaN      NaN     1.000
# Glacier Wolfpack                                                                                                   NaN      NaN     1.000
# Glacier HS Wolfpack                                                                                                NaN      NaN     1.000
# Gillman                                                                                                            NaN      NaN     1.000
# SA Hudson                                                                                                          NaN      NaN     1.000
# SA Hudson Yards -                                                                                                  NaN      NaN     1.000
# Gig Habor                                                                                                          NaN      NaN     1.000
# Gig                                                                                                                NaN      NaN     1.000
# Geroge Mason                                                                                                       NaN      NaN     1.000
# Germantown Academy                                                                                                 NaN      NaN     1.000
# Gergetown Day                                                                                                      NaN      NaN     1.000
# Georiga                                                                                                            NaN      NaN     1.000
# Georgtown                                                                                                          NaN      NaN     1.000
# Georgia State- Minessota                                                                                           NaN      NaN     1.000
# Georgia St                                                                                                         NaN      NaN     1.000
# Georgetwon                                                                                                         NaN      NaN     1.000
# GeorgetownWake                                                                                                     NaN      NaN     1.000
# x238 LASA                                                                                                          NaN      NaN     1.000

# %%
tabTourns = ballotData.tournamentName.value_counts()
tabTourns.iloc[0:20]
# Out:
# National Speech and Debate Tournament                          15580
# Glenbrooks Speech and Debate Tournament                        11725
# University of Michigan HS Debate Tournament                    10276
# Nationals Prep                                                  8993
# Greenhill Fall Classic                                          8317
# CHSSA Simulation Tournament                                     8192
# Cal Invitational UC Berkeley                                    7676
# Tournament of Champions                                         6387
# University of Michigan HS Tournament                            5561
# John Edie Holiday Debates Hosted by The Blake School            5144
# Michigan Summer Institutes                                      5068
# 1st and 2nd Year National Championships at Woodward Academy     4926
# the biggest baddest test tournament                             4880
# National Speech and Debate Season Opener hosted by UK           4816
# New York City Invitational Debate and Speech Tournament         4602
# Cal Invitational  UC Berkeley                                   4536
# Niles Township Invitational                                     4501
# GSU National College Debate Tournament                          4290
# Trevian Invitational                                            4279
# University of Georgia HS Bulldog Debates                        4270
# Name: tournamentName, dtype: int64

# %%
wikiTourns = rounds.tournament.str.lower().value_counts()
wikiTourns.iloc[0:20]
# Out:
# glenbrooks      8018
# harvard         6151
# greenhill       5664
# kentucky        4658
# gsu             4378
# blake           4274
# berkeley        4171
# any             3982
# toc             3916
# wake            3806
# emory           3737
# grapevine       3658
# stanford        3408
# st marks        3110
# bronx           2878
# all             2810
# yale            2768
# loyola          2757
# contact info    2755
# tfa state       2743
# Name: tournament, dtype: int64

# %%
rounds.columns
# Out:
# Index(['roundId', 'side', 'tournament', 'round', 'opponent', 'judge', 'report',
#        'opensourcePath', 'caselistUpdatedAt', 'teamId', 'teamName',
#        'teamDisplayName', 'notes', 'debater1First', 'debater1Last',
#        'debater2First', 'debater2Last', 'schoolId', 'schoolName',
#        'schoolDisplayName', 'state', 'chapterId', 'caselistId', 'caselistName',
#        'caselistDisplayName', 'year', 'event', 'level', 'teamSize'],
#       dtype='object')

# %%
len(ballotData[ballotData.entry_code.str.len() < 5]) / len(ballotData)
# Out:
# 0.10710507789014698

# %%
ballotData.columns
# Out:
# Index(['tournamentId', 'tournamentName', 'tournamentStart', 'tournamentEnd',
#        'city', 'state', 'country', 'webname', 'timezone', 'roundId', 'type',
#        'name', 'protocol_name', 'start_time', 'label', 'sectionId', 'room',
#        'letter', 'ballotId', 'panelId', 'entry', 'side', 'judge',
#        'judge_first', 'judge_last', 'entry_code', 'entry_name', 'flights',
#        'bye', 'winloss', 'speaker1Id', 'speaker1Score', 'speaker2Id',
#        'speaker2Score', 'judge_code', 'chair', 'entered_by', 'speaker3Id',
#        'speaker3Score', 'forfeit', 'judge_started', 'speaker4Id',
#        'speaker4Score', 'speaker5Id', 'speaker5Score', 'speakerorder',
#        'runoff', 'audited_by', 'speaker6Id', 'speaker6Score', 'speaker7Id',
#        'speaker7Score', 'speaker8Id', 'speaker8Score', 'speaker9Id',
#        'speaker9Score', 'started_by'],
#       dtype='object')

# %%
ballotData[ballotData.speaker4Score.notna() & ballotData.speaker4Score != 0]

# %%
with open('./data/example.json') as f:
  tmp = json.load(f) ['categories'][3]['events'][0]['rounds']
  with open('./data/exampleRounds.json', 'w') as f2:
    json.dump(tmp, f2, indent=2)

# %%
len(ballotData.tournamentStart[ballotData.tournamentStart.str.startswith("2")]), len(ballotData)

# %% [markdown]
# ## Results

# %%
resultData.nunique()
# Out:
# tournamentId         3836
# tournamentName       2680
# tournamentStart      2833
# tournamentEnd        2806
# city                  748
# state                  48
# country                 3
# webname              2111
# timezone               21
# label                  26
# bracket                 1
# published               1
# coach                   2
# generated            8412
# rank                  506
# place                1036
# percentile          20440
# entry              116507
# tag                   896
# value              284604
# student             41438
# round                5236
# school               1134
# dtype: int64

# %%
resultData.school.value_counts()
# Out:
# 315254.000    198
# 416758.000    166
# 422238.000    140
# 315289.000    135
# 316290.000    108
#              ...
# 434848.000      1
# 434859.000      1
# 434840.000      1
# 439038.000      1
# 438543.000      1
# Name: school, Length: 1134, dtype: int64

# %% [markdown]
# ## Cites

# %%
oldTagCounts = cites.cites.str.count(r'====') / 2
newTagCounts = cites.cites.str.count(r'####')
cites['tagCount'] = newTagCounts + oldTagCounts

# %%
cites.tagCount.sum()
# Out:
# 1387929.0

# %%
nonZeroTagCounts = cites.tagCount[cites.tagCount != 0]
zeroTagCites = cites[cites.tagCount == 0]
len(nonZeroTagCounts), nonZeroTagCounts.mean(), len(zeroTagCites)
# Out:
# (178991, 7.754183171220899, 168328)

# %%
zeroTagLink = zeroTagCites.cites.str.contains('')
zeroTagLinkCites = zeroTagCites[zeroTagLink]
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Matching

# %% [markdown]
# Ideas
#
# Find wiki teams student ids on tabroom
# - Need to match school name on wiki to schools on tabroom
# - Can use entry names to find specific teams
# - Team names and attended tournaments can help with matching
#
# Use tournament name + round num to match rounds
# - Might be hard to match tournament name
#
# Use opponent + judge + round num + side to match rounds
# - Each individually is usually easier to match

# %%
ballotData = pd.read_feather(DATA_PATH + "_ballots.feather")

# %%
(ballotData.judge_first + ballotData.judge_last).value_counts().sort_values(ascending=False)

# %%
ballotData['tournamentStart'] = pd.to_datetime(ballotData.tournamentStart, errors='coerce')
ballotData['entry_initials'] = ballotData.entry_code.str.slice(-2).str.upper()

# %%
extraSpeakers = [f"speaker{num}{t}" for num in range(3, 10) for t in ("Id", "Score")]
ballotData = ballotData.dropna(subset='tournamentStart').drop(columns=extraSpeakers, errors='ignore')

# %%
def checkBothSides(round: pd.DataFrame):
    return 1 in round.side.values and 2 in round.side.values

# %%
seasons = ballotData.groupby(pd.Grouper(key="tournamentStart", freq="AS-JUL"))
seasonFiltered = seasons.progress_apply(lambda season: season.groupby('sectionId').filter(checkBothSides))
seasonRounds = seasonFiltered.set_index([seasonFiltered.sectionId, seasonFiltered.side, seasonFiltered.index.get_level_values(1)])
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
def roundTeamJudge(round: pd.DataFrame):
  aff, neg = round.loc[:, 1, :].iloc[0], round.loc[:, 2, :].iloc[0]
  return pd.Series({
    "aff_initials": aff.entry_initials,
    "neg_initials": neg.entry_initials,
    "roundName": aff['name'],
    "judge_first": aff.judge_first.capitalize(),
    "judge_last": aff.judge_last.capitalize(),
    "season": aff.tournamentStart.year
  })

# %%
simpleRounds = seasonRounds.groupby(level=0).progress_apply(roundTeamJudge).droplevel(1).reset_index()
simpleRounds
# Out:
#         sectionId aff_initials neg_initials  roundName judge_first  \
# 0          135627           HZ           BC          1        Mike
# 1          135628           CV           DR          1       Logan
# 2          135631           BC           PS          1       Patri
# 3          135632           MM           AM          1        John
# 4          135633           CR           CE          1        Luke
# ...           ...          ...          ...        ...         ...
# 334867    6164526           MG           QY          8       Kevin
# 334868    6164527           RV           FZ          8      Colton
# 334869    6164528           LH           LM          8       David
# 334870    6164529           WW           SE          8       Scott
# 334871    6164530           HS           HA          8        Whit
#
#         judge_last  season
# 0           Hester    2012
# 1             Chin    2012
# 2        Waldinger    2012
# 3         Katsulas    2012
# 4             Hill    2012
# ...            ...     ...
# 334867        Hirn    2022
# 334868     Gilbert    2022
# 334869  Kilpatrick    2022
# 334870     Wheeler    2022
# 334871    Whitmore    2022
#
# [334872 rows x 7 columns]

# %%
simpleRounds.to_feather(DATA_PATH + "_simpleRounds.feather")

# %%
subset=['aff_initials', 'neg_initials' , 'judge_last', 'season']
duplicates = simpleRounds[simpleRounds.duplicated(keep=False, subset=subset)]
# duplicates = duplicates.dropna(axis=0, subset=['judge_first', 'judge_last'])
duplicates = duplicates[~duplicates.aff_initials.str.startswith("0")]
print(len(duplicates), len(simpleRounds))
duplicates
# Out:
# 1643 334872
#         sectionId aff_initials neg_initials  roundName judge_first  \
# 863        139905           LW           MP          4       Craig
# 943        139999           LW           MP         14       Craig
# 946        140002           KM           CP         15         Max
# 965        140022           GL           CP         16        None
# 969        140026           GL           CP         16        None
# ...           ...          ...          ...        ...         ...
# 332769    6125455           EZ           EZ          4       Andre
# 332781    6125467           EZ           NE          4      Daniel
# 334320    6156421           ON           ON          4    Jeremiah
# 334523    6160687           EP           LS          6        None
# 334860    6164519           BL           KL          8        None
#
#         judge_last  season
# 863       Hennigan    2012
# 943       Hennigan    2012
# 946         Archer    2012
# 965           None    2012
# 969           None    2012
# ...            ...     ...
# 332769      Sutton    2022
# 332781       Perez    2022
# 334320  Etcheverry    2022
# 334523        None    2022
# 334860        None    2022
#
# [1643 rows x 7 columns]

# %% [markdown]
# #### Caselist

# %%
(rounds.report.str.contains("contact", case=False)).sum()
# Out:
# 3106

# %%
policyRounds = rounds[~(
  rounds.tournament.str.lower().str.contains("contact", case=False) | 
  rounds.report.str.contains("contact", case=False) |
  (rounds.tournament == "All Tournaments")
) & (
  rounds.event == "cx"
)]
len(policyRounds), len(rounds[rounds.event == "cx"])
# Out:
# (182360, 186658)

# %%
# Could also Match AbCd but lazy
hasOpponent = policyRounds.opponent.str.match(r'.+ ([a-zA-Z]){2}$').fillna(False) | policyRounds.opponent.str.contains("&")
hasOpponent.sum(), len(policyRounds), hasOpponent.sum() / len(policyRounds)
# Out:
# (152154, 182360, 0.8343606053959202)

# %%
fullJudge = policyRounds.judge.str.match(r'^\w+ \w+$')
fullJudge.sum(), len(policyRounds), fullJudge.sum() / len(policyRounds)
# Out:
# (100270, 182360, 0.5498464575564816)

# %%
# Could also handle Finals, Semifinals etc.
roundNum = policyRounds['round'].isin(str(i) for i in range(10))
roundNum.sum(), len(policyRounds), roundNum.sum() / len(policyRounds)
# Out:
# (159715, 182360, 0.8758225488045625)

# %%
fullData = policyRounds[hasOpponent & fullJudge & roundNum].set_index("roundId")
len(fullData), len(policyRounds), len(fullData) / len(policyRounds)
# Out:
# (93489, 182360, 0.5126617679315639)

# %%
def wikiroundTeamSide(round: pd.DataFrame):
  round = round.iloc[0]
  team_initials = round.teamDisplayName[-4] + round.teamDisplayName[-2]
  opponent_initials = round.opponent[-2:].upper()
  judge_first, judge_last = round['judge'].split(" ")
  if round.side == "A":
    aff_initials, neg_initials = team_initials, opponent_initials
  else:
    aff_initials, neg_initials = opponent_initials, team_initials
  return pd.Series({
    "aff_initials": aff_initials,
    "neg_initials": neg_initials,
    "roundName": round['round'],
    "judge_first": judge_first.capitalize(),
    "judge_last": judge_last.capitalize(),
    "season": round.year
  })

# %%
wikiSimpleRounds = fullData.groupby(level=0).progress_apply(wikiroundTeamSide).reset_index().astype({'roundName': 'int64'})
wikiSimpleRounds
# Out:
#   0%|          | 0/93489 [00:00<?, ?it/s]
#        roundId aff_initials neg_initials  roundName judge_first judge_last  \
# 0       564515           RC           BC          4       Brian     Delong
# 1       564516           RC           MR          2        Tess     Botkin
# 2       564517           RC           KG          8      Edmund    Zagorin
# 3       564518           RC           LM          1        Andy     Montee
# 4       564519           RC           BO          6       Emily      Bosch
# ...        ...          ...          ...        ...         ...        ...
# 93484   966386           GS           DM          3        Will       Katz
# 93485   966388           CC           HH          3         Tim    Freehan
# 93486   966390           NE           DW          3       Maria    Sanchez
# 93487   966393           MZ           AG          2        Matt   Stannard
# 93488   966395           CZ           KL          2       Blake        Dee
#
#        season
# 0        2014
# 1        2014
# 2        2014
# 3        2014
# 4        2014
# ...       ...
# 93484    2022
# 93485    2022
# 93486    2022
# 93487    2022
# 93488    2022
#
# [93489 rows x 7 columns]

# %%
wikiSimpleRounds.to_feather(DATA_PATH + "wikiSimpleRounds.feather")

# %%
mergedRounds = pd.merge(wikiSimpleRounds, simpleRounds, how='left', on=["aff_initials", "neg_initials", "roundName", "judge_first",  "judge_last", "season"])
mergedRounds.sectionId.count(), len(policyRounds), mergedRounds.sectionId.count() / len(policyRounds)
# Out:
# (19188, 182360, 0.10522044307962272)

# %%
mergedRounds[mergedRounds.sectionId.notna()]
# Out:
#        roundId aff_initials neg_initials  roundName judge_first judge_last  \
# 23      564541           RR           NS          2         Ben    Menzies
# 25      564544           TM           RR          4     Malcolm     Gordon
# 26      564545           BQ           RR          7         Ben    Crossan
# 27      564546           MP           RR          6        Luis   Magallon
# 52      564610           CM           KR          1       Scott    Elliott
# ...        ...          ...          ...        ...         ...        ...
# 93186   962505           LS           LH          1        Todd         Le
# 93209   962665           MF           LS          2      Brooke   Erickson
# 93210   962673           CS           LS          3      Tanner     Cronce
# 93223   962901           CS           MT          2         Joe   Klopotek
# 93225   962904           MT           MM          3   Stephanie       King
#
#        season   sectionId
# 23       2014  507858.000
# 25       2014  508634.000
# 26       2014  509167.000
# 27       2014  508890.000
# 52       2014  510759.000
# ...       ...         ...
# 93186    2022 6045613.000
# 93209    2022 6048149.000
# 93210    2022 6051384.000
# 93223    2022 6118868.000
# 93225    2022 6118873.000
#
# [19188 rows x 8 columns]

# %%
# ballotData[ballotData.sectionId == 4095849]
gTmp = ballotData[ballotData.tournamentId == 12924]

# %%
# policyRounds[policyRounds.roundId == 741459]
# policyRounds[policyRounds.teamId == 63181]

# %%
fullMerged = pd.merge(policyRounds, mergedRounds, how="outer", on=['roundId'])
fullMerged = pd.merge(fullMerged, ballotData, how='outer', on=['sectionId'], suffixes=('_wiki', '_tabroom'))

# %%
counts = fullMerged.count()
